# %%
import pandas as pd

# %%
pd.read_csv('../data-sources/solarquotes-battery-comparison.csv')
# Out:
#                                   ﻿"""Product Name"""  \
# 0                                "In Depth Analysis?"
# 1                                      "Battery Type"
# 2                                  "All In One unit?"
# 3   "Price (Estimated Retail pricing in AUD incl. ...
# 4                                   "Nominal Storage"
# 5                           "Usable Storage Capacity"
# 6                                              "Pros"
# 7                                              "Cons"
# 8                                            "Weight"
# 9                                             "Power"
# 10                                 "Dimensions (WHD)"
# 11                                       "Cycle Life"
# 12                            "Round Trip Efficiency"
# 13                                "Off-grid Capable?"
# 14  "Designed for indoor or outdoor installation? ...
# 15                      "Operating temperature range"
# ...
